# %% [markdown]
# # Preprocesamiento
#
# ##### Paquetes

# %%
#install.packages('stepR')

# %%
require(stepR)
# Out:
# Loading required package: stepR
#
# Successfully loaded stepR package version 2.1-3.
# Several new functions are added in version 2.0-0. Some older functions are deprecated (still working) and may be defunct in a later version. Please read the documentation for more details.

# %% [markdown]
# **Cargando los datos**

# %%
datos = read.csv("datos.csv")
head(datos)
# Out:
#   timestamp           value
# 1 2014-04-01 00:00:00 19.76125
# 2 2014-04-01 00:05:00 20.50083
# 3 2014-04-01 00:10:00 19.96164
# 4 2014-04-01 00:15:00 21.49027
# 5 2014-04-01 00:20:00 20.18774
# 6 2014-04-01 00:25:00 19.92313

# %% [markdown]
# **Objetivo:** Definir intervalos que contengan el patrón regular.

# %%
#Número de escalones
nc = 35

# %%
#Calculando el modelo
modelo = steppath(datos$value)

#Niveles ajustados
fitg <- modelo[[nc]]

#Calculo de la volatilidad
r = diff(c(0,fitg$rightEnd))
media = unlist(sapply(1:nc, function(i){rep(fitg$value[i],r[i])}))
desv = unlist(sapply(1:nc, function(i){
                  ind = fitg$leftEnd[i]:fitg$rightEnd[i]
                  rep(sqrt(var(datos$value[ind])),r[i])
            }))
liminf = media - 1.96*desv
limsup = media + 1.96*desv

#Gráfica
plot(datos$value, type = "p", col = "aquamarine4", ylim = c(0,100))
lines(media, type = "l", col = "black")
lines(limsup, type = "l", col = "red")
lines(liminf, type = "l", col = "blue")
# Out:
# plot without title

# %% [markdown]
# **¿Cuántos escalones son necesarios?**
#
# Con **18** segmentos se explica suficiente variabilidad.

# %%
varianzas = sapply(2:50, function(i){
  fitg <- modelo[[i]]
  var(resid(fitg, datos$value))
})
varianza = var(datos$value)
plot(100*(varianzas/varianza), type =  "h",
 main = "% de variabilidad reduccido",
 ylab = "Porcentaje",
 xlab = "Núm de escalones")
# Out:
# Plot with title “% de variabilidad reduccido”

# %% [markdown]
# Con **18** segmentos se obtiene poca ***cobertura***.

# %%
#Número de escalones
nc = 18

#Niveles ajustados
fitg <- modelo[[nc]]

#Calculo de la volatilidad
r = diff(c(0,fitg$rightEnd))
media = unlist(sapply(1:nc, function(i){rep(fitg$value[i],r[i])}))
desv = unlist(sapply(1:nc, function(i){
                  ind = fitg$leftEnd[i]:fitg$rightEnd[i]
                  rep(sqrt(var(datos$value[ind])),r[i])
            }))
liminf = media - 1.96*desv
limsup = media + 1.96*desv

#Gráfica
plot(datos$value, type = "p", col = "aquamarine4", ylim = c(0,100))
lines(media, type = "l", col = "black")
lines(limsup, type = "l", col = "red")
lines(liminf, type = "l", col = "blue")
# Out:
# plot without title

# %% [markdown]
# Con **35** segmentos se obtiene buena ***cobertura***.

# %%
porc = sapply(2:70,function(nc){
        fitg <- modelo[[nc]]
        r = diff(c(0,fitg$rightEnd))
        media = unlist(sapply(1:nc, function(i){rep(fitg$value[i],r[i])}))
        desv = unlist(sapply(1:nc, function(i){
                  ind = fitg$leftEnd[i]:fitg$rightEnd[i]
                  rep(sqrt(var(datos$value[ind])),r[i])
            }))
        liminf = media - 1.96*desv
        limsup = media + 1.96*desv
        mean((liminf <= datos$value)*(datos$value<=limsup))
          })
  
plot(porc, type = "h")
points(porc)
points(x = 34, y = porc[34], col = "blue", pch = 19)
porc[30:40]
which.max(porc[30:40])
# Out:
#  [1] 0.9776 0.9808 0.9824 0.9836 0.9840 0.9836 0.9824 0.9820 0.9812 0.9812
# [11] 0.9808
# [1] 5
# plot without title

# %% [markdown]
# **¿Como cubrir el 100%?**
#
# Se redefine el intervalo al error máximo observado.

# %%
#Número de escalones
nc = 35

#Ajustando el intervalo
fitg <- modelo[[nc]]
r = diff(c(0,fitg$rightEnd))
media = unlist(sapply(1:nc, function(i){rep(fitg$value[i],r[i])}))
desv = unlist(sapply(1:nc, function(i){
                  ind = fitg$leftEnd[i]:fitg$rightEnd[i]
                  rep(sqrt(var(datos$value[ind])),r[i])
            }))
liminf = media - 1.96*desv
limsup = media + 1.96*desv

inclusion = (liminf <= datos$value)*(datos$value<=limsup)

if(any(inclusion == 0)){
    i = which(inclusion == 0)
    desv[i] = abs(datos$value[i] - media[i])
    media[i] = datos$value[i]
}

liminf = media - 1.96*desv
limsup = media + 1.96*desv
# Out:
# Warning message in media - 1.96 * desv:
# “longer object length is not a multiple of shorter object length”
# Warning message in media + 1.96 * desv:
# “longer object length is not a multiple of shorter object length”

# %%
any(inclusion == 0)
# Out:
# [1] TRUE

# %%
mean((liminf <= datos$value)*(datos$value<=limsup))
# Out:
# [1] 0.9468

# %%
#Gráfica
plot(datos$value, type = "p", col = "aquamarine4", ylim = c(0,100))
lines(media, type = "l", col = "black")
lines(limsup, type = "l", col = "red")
lines(liminf, type = "l", col = "blue")
# Out:
# plot without title

# %% [markdown]
# ### ¿Qué atributos pueden servir para predecir $Y_t$ y $\sigma_t$?

# %%
#autocorrelaciones
acf(datos$value, lag.max = 900)
# Out:
# Plot with title “Series  datos$value”

# %% [markdown]
# $Y_{t-1}$ es relevante  y al restarlo $(Y_{t} - Y_{t-1})$ simplifica las autocorrelaciones.

# %%
#autocorrelaciones
autocorr = acf(diff(datos$value, lag = 1), lag.max = 900)
# Out:
# Plot with title “Series  diff(datos$value, lag = 1)”

# %%
which( abs(autocorr$acf) > 0.2)
# Out:
# [1]   1   2 109 181 289 469 577 865

# %% [markdown]
# **Los atributos seleccionados para la predicción son:**
#
# - $Y_{t-1}$
# - $Y_{t-109}$
# - $Y_{t-181}$
# - $Y_{t-289}$.

# %% [markdown]
# ## Construyendo la matriz de entrenamiento.

# %%
Tmax = dim(datos)[1]

colnames(datos)[2] = "Y"
datos$media = media
datos$radio = desv
datos$Y1 = c(NA,datos$Y[1:(Tmax-1)])
datos$Y109 = c(rep(NA,109), datos$Y[1:(Tmax-109)])
datos$Y181 = c(rep(NA,181), datos$Y[1:(Tmax-181)])
datos$Y289 = c(rep(NA,289), datos$Y[1:(Tmax-289)])
head(datos)
# Out:
# Error in `$<-.data.frame`(`*tmp*`, radio, value = c(3.88218608796785, : replacement has 40 rows, data has 2500
# Traceback:
#
# 1. `$<-`(`*tmp*`, radio, value = c(3.88218608796785, 3.36630821746785,
#  . 3.90005451596785, 3.60168475026785, 3.38749607716785, 3.44778164496785,
#  . 3.39641112485834, 2.76370797915834, 3.60027740095834, 3.53122630685834,
#  . 4.17902176005834, 8.96415327748437, 3.23059874874107, 2.70724746674107,
#  . 4.00323515364107, 2.72935704934107, 3.58417472574108, 9.5535673575916,
#  . 3.37079048868153, 3.18571320258153, 2.9125112803113, 4.01912871281129,
#  . 2.60514841071129, 2.84724445851129, 3.70920438341129, 3.84851561671129,
#  . 7.8033344204251, 8.99066983168339, 3.96636471673451, 3.42181629003451,
#  . 4.13106514643452, 3.64211757683393, 3.91983174663393, 2.44517043313393,
#  . 2.58645768763393, 7.36084284581413, 2.74795886842559, 3.75373998942559,
#  . 3.32159057742559, 2.59664366842559))
# 2. `$<-.data.frame`(`*tmp*`, radio, value = c(3.88218608796785,
#  . 3.36630821746785, 3.90005451596785, 3.60168475026785, 3.38749607716785,
#  . 3.44778164496785, 3.39641112485834, 2.76370797915834, 3.60027740095834,
#  . 3.53122630685834, 4.17902176005834, 8.96415327748437, 3.23059874874107,
#  . 2.70724746674107, 4.00323515364107, 2.72935704934107, 3.58417472574108,
#  . 9.5535673575916, 3.37079048868153, 3.18571320258153, 2.9125112803113,
#  . 4.01912871281129, 2.60514841071129, 2.84724445851129, 3.70920438341129,
#  . 3.84851561671129, 7.8033344204251, 8.99066983168339, 3.96636471673451,
#  . 3.42181629003451, 4.13106514643452, 3.64211757683393, 3.91983174663393,
#  . 2.44517043313393, 2.58645768763393, 7.36084284581413, 2.74795886842559,
#  . 3.75373998942559, 3.32159057742559, 2.59664366842559))
# 3. stop(sprintf(ngettext(N, "replacement has %d row, data has %d",
#  .     "replacement has %d rows, data has %d"), N, nrows), domain = NA)

# %%
View(datos[(Tmax-10):Tmax,])

# %%
write.table(datos,"datos2.csv", dec = ".", sep = ";")
